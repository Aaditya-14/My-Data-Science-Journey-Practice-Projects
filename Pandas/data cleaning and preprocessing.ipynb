# %%
import pandas as pd

# %%
data=pd.read_csv("sample_data_cleaning.csv")

# %%
data
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
data.isnull() # check null value|
# Out:
#      Name    Age  Gender  Email   City  Salary  JoinDate
# 0   False  False   False  False  False   False     False
# 1   False   True   False  False  False   False     False
# 2   False  False   False  False  False    True     False
# 3   False  False   False  False  False   False     False
# 4   False   True   False   True  False   False     False
# 5   False  False   False  False  False   False     False
# 6   False  False   False  False  False    True     False
# 7   False  False    True  False  False   False     False
# 8   False   True   False  False   True   False     False
# 9   False  False   False  False  False   False     False
# 10  False  False   False  False  False   False     False
# 11  False  False    True  False  False   False     False
# 12  False  False   False  False  False   False     False
# 13  False   True   False  False  False   False     False
# 14  False  False   False   True  False    True     False
# ...

# %%
data.isnull().sum()# sum of null value
# Out:
# Name        0
# Age         6
# Gender      2
# Email       3
# City        2
# Salary      4
# JoinDate    0
# dtype: int64

# %%
data.dropna() #drop row without null value
# Out:
#            Name   Age  Gender                       Email          City  \
# 0      John Doe  29.0    Male          john.doe@gmail.com      New York
# 3      Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 5   Emily Davis  45.0  Female          emily.davis@domain         Miami
# 9    Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10   Tony Stark  48.0    Male    tony@starkindustries.com      new york
# 12   Clark Kent  33.0    Male  clark.kent@dailyplanet.com    Metropolis
# 15  Barry Allen  32.0    Male       barry.allen@speed.com  central city
# 19    Nick Fury  55.0    Male        nick.fury@shield.org    Washington
#
#       Salary    JoinDate
# 0    55000.0  2021-05-14
# 3    54000.0  2022-08-12
# 5    70000.0  2018-11-25
# 9    59000.0  2023-01-09
# 10  150000.0  2015-04-22
# 12  115000.0  2017-07-07
# 15   72000.0  2018-03-03
# 19   95000.0  2015-10-31

# %%
data.dropna(axis=1) #drop column without null value
# Out:
#                 Name    JoinDate
# 0           John Doe  2021-05-14
# 1         Jane Smith  2019-03-21
# 2        Mike Taylor  2020-07-01
# 3           Anna Lee  2022-08-12
# 4        Chris Brown  2021-01-30
# 5        Emily Davis  2018-11-25
# 6        Robert King  2020-12-10
# 7          Sara Khan  2022-02-18
# 8         Steve Jobs  2017-06-05
# 9         Lara Croft  2023-01-09
# 10        Tony Stark  2015-04-22
# 11       Bruce Wayne  2016-12-30
# 12        Clark Kent  2017-07-07
# 13      Peter Parker  2019-09-15
# 14      Diana Prince  2020-11-01
# 15       Barry Allen  2018-03-03
# 16  Natasha Romanoff  2020-10-12
# 17    Wanda Maximoff  2021-08-19
# 18            Vision  2019-06-06
# 19         Nick Fury  2015-10-31

# %%
data.fillna(0)# fill null value with 0
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   0.0  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   0.0    Male                           0       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0       0          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   0.0    Male        steve.jobs@apple.com             0
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
# add average value in missing place
data["Salary"] = data["Salary"].fillna(data["Salary"].mean())

# %%
data
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
data.ffill() #fill missing value with last known value from top
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith  29.0  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown  27.0    Male          anna_lee@yahoo.com       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0    male          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs  31.0    Male        steve.jobs@apple.com       Atlanta
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
data.bfill() #fill missing value with last known value from buttom
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith  34.0  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown  45.0    Male          emily.davis@domain       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0    Male          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs  26.0    Male        steve.jobs@apple.com       Seattle
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %% [raw]
# Detect and remove duplicate value

# %%
import pandas as pd

# %%
data=pd.read_csv("duplicate.csv")

# %%
data
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
data.duplicated()# check Duplicate values
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# 22     True
# dtype: bool

# %%
data.drop_duplicates() # it will drop duplicate values
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
#when rows is drop then the index indexing number will be ziczac

# %%
#for specific rows and column
data.drop_duplicates(subset=["Name"])
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %% [markdown]
# String Operation with .str

# %%
data["Name"].str.lower()#it make all name in lowercase
# Out:
# 0             john doe
# 1           jane smith
# 2          mike taylor
# 3             anna lee
# 4          chris brown
# 5          emily davis
# 6          robert king
# 7            sara khan
# 8           steve jobs
# 9           lara croft
# 10          tony stark
# 11         bruce wayne
# 12          clark kent
# 13        peter parker
# 14        diana prince
# 15         barry allen
# 16    natasha romanoff
# 17      wanda maximoff
# 18              vision
# 19           nick fury
# 20         mike taylor
# 21         emily davis
# 22          tony stark
# Name: Name, dtype: object

# %%
data["Name"].str.contains("vision",case=False)  #it show values which contain vision
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# Name: Name, dtype: bool

# %%
data["Email"].str.split("@") # It split the email from @ and put it in list
# Out:
# 0             [john.doe, gmail.com]
# 1         [jane.smith, outlook.com]
# 2               [miketaylor, gmail]
# 3             [anna_lee, yahoo.com]
# 4                               NaN
# 5             [emily.davis, domain]
# 6          [robert.king, gmail.com]
# 7            [sarakhan, , mail.com]
# 8           [steve.jobs, apple.com]
# 9           [lara.croft, gmail.com]
# 10      [tony, starkindustries.com]
# 11         [bruce.wayne, wayne.com]
# 12    [clark.kent, dailyplanet.com]
# 13              [peter, marvel.com]
# 14                              NaN
# 15         [barry.allen, speed.com]
# 16            [natasha, shield.com]
# 17                              NaN
# 18           [vision, avengers.com]
# 19          [nick.fury, shield.org]
# 20              [miketaylor, gmail]
# 21            [emily.davis, domain]
# 22      [tony, starkindustries.com]
# Name: Email, dtype: object

# %%
data["Age"]
# Out:
# 0     29.0
# 1      NaN
# 2     34.0
# 3     27.0
# 4      NaN
# 5     45.0
# 6     38.0
# 7     31.0
# 8      NaN
# 9     26.0
# 10    48.0
# 11    35.0
# 12    33.0
# 13     NaN
# 14    28.0
# 15    32.0
# 16     NaN
# 17    30.0
# 18     NaN
# 19    55.0
# 20    34.0
# 21    45.0
# 22    48.0
# Name: Age, dtype: float64

# %%
data2=data.ffill().copy()# i copy this data

# %%
data2
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith  29.0  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown  27.0    Male          anna_lee@yahoo.com       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0    male          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs  31.0    Male        steve.jobs@apple.com       Atlanta
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
data2["Age"] = data2["Age"].astype("int32")# convert Age float type in int 32

# %%
data2["Age"]
# Out:
# 0     29
# 1     29
# 2     34
# 3     27
# 4     27
# 5     45
# 6     38
# 7     31
# 8     31
# 9     26
# 10    48
# 11    35
# 12    33
# 13    33
# 14    28
# 15    32
# 16    32
# 17    30
# 18    30
# 19    55
# 20    34
# 21    45
# 22    48
# Name: Age, dtype: int32

# %%
data["JoinDate"] = pd.to_datetime(data["JoinDate"])

# %%
data
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
print(type(data["JoinDate"][0]))
# Output: <class 'str'>
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
print(data["JoinYear"] ==data["JoinDate"].dt.year)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# dtype: bool

# %% [markdown]
# Appling function

# %%
data2
# Out:
#                 Name    Age  Gender                       Email          City  \
# 0           John Doe  Adult    Male          john.doe@gmail.com      New York
# 1         Jane Smith  Adult  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  Adult    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  Adult  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown  Adult    Male          anna_lee@yahoo.com       Houston
# 5        Emily Davis  Adult  Female          emily.davis@domain         Miami
# 6        Robert King  Adult    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  Adult    male          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs  Adult    Male        steve.jobs@apple.com       Atlanta
# 9         Lara Croft  Adult  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  Adult    Male    tony@starkindustries.com      new york
# ...

# %%
data
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
data.ffill().copy()
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith  29.0  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown  27.0    Male          anna_lee@yahoo.com       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0    male          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs  31.0    Male        steve.jobs@apple.com       Atlanta
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
data["AgeGroup"] = data["Age"].apply(lambda x: "Adult" if x >= 18 else "Minor").copy()

# %%
data
# Out:
#                 Name   Age  Gender                       Email          City  \
# 0           John Doe  29.0    Male          john.doe@gmail.com      New York
# 1         Jane Smith   NaN  FEMALE      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0    Male            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0  female          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN    Male                         NaN       Houston
# 5        Emily Davis  45.0  Female          emily.davis@domain         Miami
# 6        Robert King  38.0    male       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0     NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN    Male        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0  FEMALE        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0    Male    tony@starkindustries.com      new york
# ...

# %%
#maps function
gender_maps = {"Male": "M", "Female": "F"}
data["Gender"] = data["Gender"].map(gender_maps)

# %%
data
# Out:
#                 Name   Age Gender                       Email          City  \
# 0           John Doe  29.0      M          john.doe@gmail.com      New York
# 1         Jane Smith   NaN    NaN      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0      M            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0    NaN          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN      M                         NaN       Houston
# 5        Emily Davis  45.0      F          emily.davis@domain         Miami
# 6        Robert King  38.0    NaN       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0    NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN      M        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0    NaN        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0      M    tony@starkindustries.com      new york
# ...

# %%
data["Agegroup"]=data["AgeGroup"].replace({"Adult":"A","Minor":"M"}).copy()

# %%
data
# Out:
#                 Name   Age Gender                       Email          City  \
# 0           John Doe  29.0      M          john.doe@gmail.com      New York
# 1         Jane Smith   NaN    NaN      jane.smith@outlook.com   los angeles
# 2        Mike Taylor  34.0      M            miketaylor@gmail       Chicago
# 3           Anna Lee  27.0    NaN          anna_lee@yahoo.com        Boston
# 4        Chris Brown   NaN      M                         NaN       Houston
# 5        Emily Davis  45.0      F          emily.davis@domain         Miami
# 6        Robert King  38.0    NaN       robert.king@gmail.com        Dallas
# 7          Sara Khan  31.0    NaN          sarakhan@@mail.com       Atlanta
# 8         Steve Jobs   NaN      M        steve.jobs@apple.com           NaN
# 9         Lara Croft  26.0    NaN        lara.croft@gmail.com       Seattle
# 10        Tony Stark  48.0      M    tony@starkindustries.com      new york
# ...
