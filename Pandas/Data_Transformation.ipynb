# %%
import pandas as pd

# %%
data=pd.read_csv("employee_data.csv")

# %%
data
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
#
#         Location
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4       New York
# ...

# %%
data.sort_values("Age")# Ascending sort
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
#
#         Location
# 8       New York
# 0       New York
# 5  San Francisco
# 6    Los Angeles
# 1    Los Angeles
# ...

# %%
data.sort_values("Age" , ascending=False)# Descending
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
#
#         Location
# 4       New York
# 2        Chicago
# 9        Chicago
# 7         Dallas
# 3        Houston
# ...

# %%
data.sort_values(["Age", "Salary"]) # Sort by multiple columns
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
#
#         Location
# 8       New York
# 0       New York
# 5  San Francisco
# 6    Los Angeles
# 1    Los Angeles
# ...

# %%
data.reset_index() #reset the old index data
# Out:
#    index EmployeeID FirstName  LastName  Gender Department    JoinDate  \
# 0      0       E001      John       Doe    Male         IT  2019-03-15
# 1      1       E002      Jane     Smith  Female         HR  2020-06-20
# 2      2       E003     Alice   Johnson  Female  Marketing  2018-11-10
# 3      3       E004    Robert     Brown    Male    Finance  2021-01-05
# 4      4       E005   Michael     Davis    Male         IT  2017-09-12
# 5      5       E006     Linda    Miller  Female  Marketing  2022-02-14
# 6      6       E007     David    Wilson    Male         HR  2020-04-22
# 7      7       E008     Susan     Moore  Female    Finance  2019-12-03
# 8      8       E009     James    Taylor    Male         IT  2023-03-18
# 9      9       E010     Karen  Anderson  Female         HR  2016-08-25
#
#    Salary  Age       Location
# 0   55000   28       New York
# 1   48000   32    Los Angeles
# 2   62000   41        Chicago
# 3   73000   36        Houston
# 4   69000   45       New York
# ...

# %%
data.reset_index(drop=True) #Drop the old index
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
#
#         Location
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4       New York
# ...

# %%
data.reset_index(drop=True, inplace=True)# inplace change values in old data

# %%
data
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
#
#         Location
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4       New York
# ...

# %%
data.sort_index() #sort the index value if we have drop some rows
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
#
#         Location
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4       New York
# ...

# %%
data["salary_avg"] = data["Salary"].rank().copy()# Default: average method
# df["Rank"] = df["Score"].rank(method="dense")   # 1, 2, 2, 3

# %%
data
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
#
#         Location  salary_avg
# 0       New York         5.0
# 1    Los Angeles         2.0
# 2        Chicago         7.0
# ...

# %%
data["salary_avg"] = data["Salary"].rank(method='dense').copy()

# %%
data
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
#
#         Location  salary_avg
# 0       New York         5.0
# 1    Los Angeles         2.0
# 2        Chicago         7.0
# ...

# %%
#renaming the rows and column

# %%
# df.rename(columns={"oldName": "newName"}, inplace=True)
# df.rename(index={0: "row1", 1: "row2"}, inplace=True)

data.rename(columns={"salary_avg": "Average_Salary"}, inplace=True)

# %%
data
# Out:
#   EmployeeID FirstName  LastName  Gender Department    JoinDate  Salary  Age  \
# 0       E001      John       Doe    Male         IT  2019-03-15   55000   28
# 1       E002      Jane     Smith  Female         HR  2020-06-20   48000   32
# 2       E003     Alice   Johnson  Female  Marketing  2018-11-10   62000   41
# 3       E004    Robert     Brown    Male    Finance  2021-01-05   73000   36
# 4       E005   Michael     Davis    Male         IT  2017-09-12   69000   45
# 5       E006     Linda    Miller  Female  Marketing  2022-02-14   52000   29
# 6       E007     David    Wilson    Male         HR  2020-04-22   50000   31
# 7       E008     Susan     Moore  Female    Finance  2019-12-03   71000   38
# 8       E009     James    Taylor    Male         IT  2023-03-18   58000   27
# 9       E010     Karen  Anderson  Female         HR  2016-08-25   46000   40
#
#         Location  Average_Salary
# 0       New York             5.0
# 1    Los Angeles             2.0
# ...

# %%
data.rename(index={0: "row1", 1: "row2"}, inplace=True)

# %%
data
# Out:
#      FirstName  LastName  Gender EmployeeID Department    JoinDate  Salary  \
# row1      John       Doe    Male       E001         IT  2019-03-15   55000
# row2      Jane     Smith  Female       E002         HR  2020-06-20   48000
# 2        Alice   Johnson  Female       E003  Marketing  2018-11-10   62000
# 3       Robert     Brown    Male       E004    Finance  2021-01-05   73000
# 4      Michael     Davis    Male       E005         IT  2017-09-12   69000
# 5        Linda    Miller  Female       E006  Marketing  2022-02-14   52000
# 6        David    Wilson    Male       E007         HR  2020-04-22   50000
# 7        Susan     Moore  Female       E008    Finance  2019-12-03   71000
# 8        James    Taylor    Male       E009         IT  2023-03-18   58000
# 9        Karen  Anderson  Female       E010         HR  2016-08-25   46000
#
#            Location  Average_Salary
# row1       New York             5.0
# row2    Los Angeles             2.0
# ...

# %%
data = data[["FirstName", "LastName", "Gender","EmployeeID","Department","JoinDate","Salary","Location","Average_Salary"]]   # Reorder as desired

# %%
data
# Out:
#      FirstName  LastName  Gender EmployeeID Department    JoinDate  Salary  \
# row1      John       Doe    Male       E001         IT  2019-03-15   55000
# row2      Jane     Smith  Female       E002         HR  2020-06-20   48000
# 2        Alice   Johnson  Female       E003  Marketing  2018-11-10   62000
# 3       Robert     Brown    Male       E004    Finance  2021-01-05   73000
# 4      Michael     Davis    Male       E005         IT  2017-09-12   69000
# 5        Linda    Miller  Female       E006  Marketing  2022-02-14   52000
# 6        David    Wilson    Male       E007         HR  2020-04-22   50000
# 7        Susan     Moore  Female       E008    Finance  2019-12-03   71000
# 8        James    Taylor    Male       E009         IT  2023-03-18   58000
# 9        Karen  Anderson  Female       E010         HR  2016-08-25   46000
#
#            Location  Average_Salary
# row1       New York             5.0
# row2    Los Angeles             2.0
# ...

# %%
# Using Python FInction
cols = ["JoinDate"] + [col for col in data.columns if col != "joinDate"]
data = data[cols]

# %%
data
# Out:
#         JoinDate FirstName  LastName  Gender EmployeeID Department  \
# row1  2019-03-15      John       Doe    Male       E001         IT
# row2  2020-06-20      Jane     Smith  Female       E002         HR
# 2     2018-11-10     Alice   Johnson  Female       E003  Marketing
# 3     2021-01-05    Robert     Brown    Male       E004    Finance
# 4     2017-09-12   Michael     Davis    Male       E005         IT
# 5     2022-02-14     Linda    Miller  Female       E006  Marketing
# 6     2020-04-22     David    Wilson    Male       E007         HR
# 7     2019-12-03     Susan     Moore  Female       E008    Finance
# 8     2023-03-18     James    Taylor    Male       E009         IT
# 9     2016-08-25     Karen  Anderson  Female       E010         HR
#
#         JoinDate  Salary       Location  Average_Salary
# row1  2019-03-15   55000       New York             5.0
# row2  2020-06-20   48000    Los Angeles             2.0
# 2     2018-11-10   62000        Chicago             7.0
# ...
