# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,3,4,5,6,7,45,76,32,65,76])
y=np.sin(x)

# %%
sns.set_theme(style="whitegrid")

# %%
sns.lineplot(x=x,y=y)
plt.title('Beautiful Line Plot')
# Out:
# Text(0.5, 1.0, 'Beautiful Line Plot')
